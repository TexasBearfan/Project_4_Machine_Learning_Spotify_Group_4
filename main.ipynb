# %%
import pandas as pd

# %%
file='data/Spotify_Dataset_V3.csv'

# %%
df=pd.read_csv(file,delimiter=';')
df.head()
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758   -5176.0        0.033         0.483
# 1         0.668   0.758   -5176.0        0.033         0.483
# 2         0.652   0.800   -4019.0        0.061         0.143
# 3         0.812   0.479   -5678.0        0.333         0.213
# 4         0.812   0.479   -5678.0        0.333         0.213
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# ...

# %%
df=df[['Rank','Date','Title','Danceability','Energy','Loudness','Speechiness','Acousticness','Instrumentalness','Valence','id']]
df.head()
# Out:
#    Rank        Date            Title  Danceability  Energy  Loudness  \
# 0     1  29/05/2023  Ella Baila Sola         0.668   0.758   -5176.0
# 1     1  29/05/2023  Ella Baila Sola         0.668   0.758   -5176.0
# 2     2  29/05/2023   WHERE SHE GOES         0.652   0.800   -4019.0
# 3     3  29/05/2023  La Bebe - Remix         0.812   0.479   -5678.0
# 4     3  29/05/2023  La Bebe - Remix         0.812   0.479   -5678.0
#
#    Speechiness  Acousticness  Instrumentalness  Valence  \
# 0        0.033         0.483             0.000    0.834
# 1        0.033         0.483             0.000    0.834
# 2        0.061         0.143             0.629    0.234
# 3        0.333         0.213             0.000    0.559
# 4        0.333         0.213             0.000    0.559
#
#                        id
# 0  3qQbCzHBycnDpGskqOWY0E
# 1  3qQbCzHBycnDpGskqOWY0E
# 2  7ro0hRteUMfnOioTFI5TG1
# 3  2UW7JaomAMuX9pZrjVpHAU
# 4  2UW7JaomAMuX9pZrjVpHAU

# %%
df=df.drop_duplicates()
df.head()
# Out:
#    Rank        Date              Title  Danceability  Energy  Loudness  \
# 0     1  29/05/2023    Ella Baila Sola         0.668   0.758   -5176.0
# 2     2  29/05/2023     WHERE SHE GOES         0.652   0.800   -4019.0
# 3     3  29/05/2023    La Bebe - Remix         0.812   0.479   -5678.0
# 5     4  29/05/2023  Cupid - Twin Ver.         0.783   0.592   -8332.0
# 6     5  29/05/2023          un x100to         0.569   0.724   -4076.0
#
#    Speechiness  Acousticness  Instrumentalness  Valence  \
# 0        0.033         0.483             0.000    0.834
# 2        0.061         0.143             0.629    0.234
# 3        0.333         0.213             0.000    0.559
# 5        0.033         0.435             0.000    0.726
# 6        0.047         0.228             0.000    0.562
#
#                        id
# 0  3qQbCzHBycnDpGskqOWY0E
# 2  7ro0hRteUMfnOioTFI5TG1
# 3  2UW7JaomAMuX9pZrjVpHAU
# 5  7FbrGaHYVDmfr7KoLIZnQ7
# 6  6pD0ufEQq0xdHSsRbg9LBK

# %%
df['Date'].nunique()
# Out:
# 2336

# %%
df['Date'].unique()
# Out:
# array(['29/05/2023', '28/05/2023', '27/05/2023', ..., '03/01/2017',
#        '02/01/2017', '01/01/2017'], dtype=object)

# %%
df['Dated_date']=pd.to_datetime(df['Date'])
df.head()
# Out:
# C:\Users\jacqu\AppData\Local\Temp\ipykernel_9476\449627933.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Dated_date']=pd.to_datetime(df['Date'])
#    Rank        Date              Title  Danceability  Energy  Loudness  \
# 0     1  29/05/2023    Ella Baila Sola         0.668   0.758   -5176.0
# 2     2  29/05/2023     WHERE SHE GOES         0.652   0.800   -4019.0
# 3     3  29/05/2023    La Bebe - Remix         0.812   0.479   -5678.0
# 5     4  29/05/2023  Cupid - Twin Ver.         0.783   0.592   -8332.0
# 6     5  29/05/2023          un x100to         0.569   0.724   -4076.0
#
#    Speechiness  Acousticness  Instrumentalness  Valence  \
# 0        0.033         0.483             0.000    0.834
# 2        0.061         0.143             0.629    0.234
# 3        0.333         0.213             0.000    0.559
# ...

# %%
#between may 30 2022 to may 29 2023
dated_Df=df.loc[df['Dated_date']>='2022-05-30']
dated_Df.tail()
# Out:
#         Rank        Date                        Title  Danceability  Energy  \
# 103649    40  30/05/2022             Yo No Soy Celoso         0.872   0.588
# 103650   127  30/05/2022  Yo Voy (feat. Daddy Yankee)         0.808   0.697
# 103651   106  30/05/2022                     Yonaguni         0.644   0.648
# 103652   183  30/05/2022                    You Right         0.828   0.621
# 103654   184  30/05/2022                         ZOOM         0.874   0.600
#
#         Loudness  Speechiness  Acousticness  Instrumentalness  Valence  \
# 103649   -6276.0        0.049         0.275             0.000    0.930
# 103650   -5899.0        0.241         0.041             0.000    0.554
# 103651   -4601.0        0.118         0.276             0.000    0.440
# 103652   -6414.0        0.057         0.016             0.002    0.436
# 103654   -6064.0        0.158         0.009             0.000    0.457
#
#                             id Dated_date
# ...

# %%
dated_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73401 entries, 0 to 103654
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              73401 non-null  int64
#  1   Date              73401 non-null  object
#  2   Title             73401 non-null  object
#  3   Danceability      73401 non-null  float64
#  4   Energy            73401 non-null  float64
#  5   Loudness          73401 non-null  float64
#  6   Speechiness       73401 non-null  float64
#  7   Acousticness      73401 non-null  float64
#  8   Instrumentalness  73401 non-null  float64
#  9   Valence           73401 non-null  float64
#  10  id                73401 non-null  object
#  11  Dated_date        73401 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(1), object(3)
# memory usage: 7.3+ MB

# %%
df=pd.read_csv(file,delimiter=';')
df.head()
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758   -5176.0        0.033         0.483
# 1         0.668   0.758   -5176.0        0.033         0.483
# 2         0.652   0.800   -4019.0        0.061         0.143
# 3         0.812   0.479   -5678.0        0.333         0.213
# 4         0.812   0.479   -5678.0        0.333         0.213
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# ...

# %%
df=df[['Rank','Date','Artists','Nationality','Song URL','Continent','Artist (Ind.)','Title','Danceability','Energy','Loudness','Speechiness','Acousticness','Instrumentalness','Valence','id']]
df.head()
# Out:
#    Rank        Date                     Artists  Nationality  \
# 0     1  29/05/2023  Eslabon Armado, Peso Pluma       Mexico
# 1     1  29/05/2023  Eslabon Armado, Peso Pluma       Mexico
# 2     2  29/05/2023                   Bad Bunny  Puerto Rico
# 3     3  29/05/2023       Yng Lvcas, Peso Pluma       Mexico
# 4     3  29/05/2023       Yng Lvcas, Peso Pluma       Mexico
#
#                                             Song URL      Continent  \
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...  Latin-America
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...  Latin-America
# 2  https://open.spotify.com/track/7ro0hRteUMfnOio...  Latin-America
# 3  https://open.spotify.com/track/2UW7JaomAMuX9pZ...  Latin-America
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...  Latin-America
#
#     Artist (Ind.)            Title  Danceability  Energy  Loudness  \
# 0  Eslabon Armado  Ella Baila Sola         0.668   0.758   -5176.0
# ...

# %%
df['Dated_date']=pd.to_datetime(df['Date'])
df.head()
# Out:
# C:\Users\jacqu\AppData\Local\Temp\ipykernel_9476\449627933.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Dated_date']=pd.to_datetime(df['Date'])
#    Rank        Date                     Artists  Nationality  \
# 0     1  29/05/2023  Eslabon Armado, Peso Pluma       Mexico
# 1     1  29/05/2023  Eslabon Armado, Peso Pluma       Mexico
# 2     2  29/05/2023                   Bad Bunny  Puerto Rico
# 3     3  29/05/2023       Yng Lvcas, Peso Pluma       Mexico
# 4     3  29/05/2023       Yng Lvcas, Peso Pluma       Mexico
#
#                                             Song URL      Continent  \
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...  Latin-America
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...  Latin-America
# 2  https://open.spotify.com/track/7ro0hRteUMfnOio...  Latin-America
# ...

# %%
dated_Df=df.loc[df['Dated_date']>='2022-05-30']
dated_Df.tail()
# Out:
#         Rank        Date               Artists    Nationality  \
# 103650   127  30/05/2022         Zion & Lennox    Puerto Rico
# 103651   106  30/05/2022             Bad Bunny    Puerto Rico
# 103652   183  30/05/2022  Doja Cat, The Weeknd  United States
# 103653   183  30/05/2022  Doja Cat, The Weeknd         Canada
# 103654   184  30/05/2022                 Jessi  United States
#
#                                                  Song URL      Continent  \
# 103650  https://open.spotify.com/track/5gflgO9EPbIBf16...  Latin-America
# 103651  https://open.spotify.com/track/2JPLbjOn0wPCngE...  Latin-America
# 103652  https://open.spotify.com/track/0k4d5YPDr1r7FX7...  Anglo-America
# 103653  https://open.spotify.com/track/0k4d5YPDr1r7FX7...  Anglo-America
# 103654  https://open.spotify.com/track/4IaxDf2FixiQXq0...  Anglo-America
#
#         Artist (Ind.)                        Title  Danceability  Energy  \
# 103650  Zion & Lennox  Yo Voy (feat. Daddy Yankee)         0.808   0.697
# ...

# %%
dated_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103655 entries, 0 to 103654
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Rank              103655 non-null  int64
#  1   Date              103655 non-null  object
#  2   Artists           103655 non-null  object
#  3   Nationality       103655 non-null  object
#  4   Song URL          103655 non-null  object
#  5   Continent         103655 non-null  object
#  6   Artist (Ind.)     103655 non-null  object
#  7   Title             103655 non-null  object
#  8   Danceability      103655 non-null  float64
#  9   Energy            103655 non-null  float64
#  10  Loudness          103655 non-null  float64
#  11  Speechiness       103655 non-null  float64
#  12  Acousticness      103655 non-null  float64
#  13  Instrumentalness  103655 non-null  float64
#  14  Valence           103655 non-null  float64
#  15  id                103655 non-null  object
# ...

# %%
dated_Df['Dated_date'].nunique()
# Out:
# 365

# %%
def date2num(date_time):
  d, m, y = date_time.split('/')
  num = int(d)*10 + int(m)*100
  return num

# %%
import numpy as np
date_features = []
for d in list(dated_Df['Date']):
  date_features.append(date2num(d))
date_features = np.array(date_features)
date_features_normalized = (date_features - np.min(date_features))/(np.max(date_features) - np.min(date_features))

# %%
dated_Df['Date_value']=date_features_normalized
dated_Df.head()
# Out:
# C:\Users\jacqu\AppData\Local\Temp\ipykernel_9476\326589488.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dated_Df['Date_value']=date_features_normalized
#    Rank        Date                     Artists  Nationality  \
# 0     1  29/05/2023  Eslabon Armado, Peso Pluma       Mexico
# 1     1  29/05/2023  Eslabon Armado, Peso Pluma       Mexico
# 2     2  29/05/2023                   Bad Bunny  Puerto Rico
# 3     3  29/05/2023       Yng Lvcas, Peso Pluma       Mexico
# 4     3  29/05/2023       Yng Lvcas, Peso Pluma       Mexico
#
#                                             Song URL      Continent  \
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...  Latin-America
# ...

# %%
processed_df=dated_Df[['Danceability','Energy','Loudness','Speechiness','Acousticness','Instrumentalness','Valence','Date_value']]
processed_df.head()
# Out:
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758   -5176.0        0.033         0.483
# 1         0.668   0.758   -5176.0        0.033         0.483
# 2         0.652   0.800   -4019.0        0.061         0.143
# 3         0.812   0.479   -5678.0        0.333         0.213
# 4         0.812   0.479   -5678.0        0.333         0.213
#
#    Instrumentalness  Valence  Date_value
# 0             0.000    0.834    0.485714
# 1             0.000    0.834    0.485714
# 2             0.629    0.234    0.485714
# 3             0.000    0.559    0.485714
# 4             0.000    0.559    0.485714

# %%
date_grouped_data=processed_df.groupby('Date_value')
grouped_df=date_grouped_data.mean()
grouped_df.head()
# Out:
#             Danceability    Energy     Loudness  Speechiness  Acousticness  \
# Date_value
# 0.000000        0.685187  0.681745 -5075.457966     0.094806      0.245143
# 0.007143        0.672448  0.657094 -5327.508271     0.094097      0.235910
# 0.014286        0.670435  0.655633 -5319.512657     0.090640      0.231837
# 0.021429        0.671071  0.653727 -5309.759156     0.090727      0.234940
# 0.028571        0.671465  0.661781 -5287.006569     0.090951      0.230889
#
#             Instrumentalness   Valence
# Date_value
# 0.000000            0.013776  0.530327
# 0.007143            0.015604  0.490514
# 0.014286            0.015869  0.491442
# 0.021429            0.015936  0.488418
# 0.028571            0.017990  0.481115

# %%
import matplotlib.pyplot as plt
plot=grouped_df.plot.line(y=['Danceability','Energy','Valence','Acousticness'])
plt.savefig('Images/4_variable_plot.png')
plot
# Out:
# <Axes: xlabel='Date_value'>

# %%
plot=grouped_df.plot.line(y=['Loudness'])
plt.savefig('Images/loudness_plot.png')
plot
# Out:
# <Axes: xlabel='Date_value'>

# %%
plot=grouped_df.plot.line(y=['Instrumentalness'])
plt.savefig('Images/Instrumentalness_plot.png')
plot
# Out:
# <Axes: xlabel='Date_value'>

# %%
plot=grouped_df.plot.line(y=['Speechiness'])
plt.savefig('Images/Speechiness_plot.png')
plot
# Out:
# <Axes: xlabel='Date_value'>

# %%
dated_Df=dated_Df[['Rank','Date','Title','Danceability','Energy','Loudness','Speechiness','Acousticness','Instrumentalness','Valence','id','Date_value']]
dated_Df.head()
# Out:
#    Rank        Date            Title  Danceability  Energy  Loudness  \
# 0     1  29/05/2023  Ella Baila Sola         0.668   0.758   -5176.0
# 1     1  29/05/2023  Ella Baila Sola         0.668   0.758   -5176.0
# 2     2  29/05/2023   WHERE SHE GOES         0.652   0.800   -4019.0
# 3     3  29/05/2023  La Bebe - Remix         0.812   0.479   -5678.0
# 4     3  29/05/2023  La Bebe - Remix         0.812   0.479   -5678.0
#
#    Speechiness  Acousticness  Instrumentalness  Valence  \
# 0        0.033         0.483             0.000    0.834
# 1        0.033         0.483             0.000    0.834
# 2        0.061         0.143             0.629    0.234
# 3        0.333         0.213             0.000    0.559
# 4        0.333         0.213             0.000    0.559
#
#                        id  Date_value
# 0  3qQbCzHBycnDpGskqOWY0E    0.485714
# 1  3qQbCzHBycnDpGskqOWY0E    0.485714
# 2  7ro0hRteUMfnOioTFI5TG1    0.485714
# 3  2UW7JaomAMuX9pZrjVpHAU    0.485714
# ...

# %%
dated_Df.to_csv('data/Big_Data_2022_05_30.csv')
